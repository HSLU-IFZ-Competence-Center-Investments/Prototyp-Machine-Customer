# %%
from blockrun_llm import LLMClient
from eth_account import Account
from blockrun_llm import LLMClient, APIError, PaymentError


# avaliable models and costs: https://pypi.org/project/blockrun-llm/0.7.5/

# %%
from dotenv import load_dotenv
import os

load_dotenv()
BLOCKRUN_WALLET_KEY = os.getenv("BLOCKRUN_WALLET_KEY")
if not BLOCKRUN_WALLET_KEY.startswith("0x"):
    BLOCKRUN_WALLET_KEY = "0x" + BLOCKRUN_WALLET_KEY

# %%
"""
Setting Up Your Wallet
1. Create a wallet on Base network (Coinbase Wallet, MetaMask, etc.)
2. Get some ETH on Base for gas (small amount, ~$1) -> get from Coinbase -> needs verification
3. Get USDC on Base for API payments
4. Export your private key and set it as BLOCKRUN_WALLET_KEY in your .env file
"""

address = "0x78C5d75B007FC77Fe811Aa9773a7Cb88F2d955aB"
# Mainnet client — uses real USDC on Base mainnet
client = LLMClient(private_key=BLOCKRUN_WALLET_KEY)
bal_before = client.get_balance()
print("Balance before execution:", bal_before)
try:
    # response = client.smart_chat(prompt="Can you explain me zero knowledge proof in blockchain?", routing_profile="eco")
    # print("Response model:", response.model)
    response = client.chat(prompt="Can you explain me zero knowledge proof in blockchain?", model="openai/gpt-5-mini")
    print(response)
except PaymentError as e:
    print(f"Payment failed: {e}")
    # Check your USDC balance
except APIError as e:
    print(f"API error ({e.status_code}): {e}")

print("Spending cost:", client.get_spending())
# Out:
# Balance before execution: 9.988514
# Sure — here’s a clear, practical explanation of zero-knowledge proofs (ZKPs) in the context of blockchain, broken into simple parts.
#
# What a zero-knowledge proof is (high-level)
# - A ZKP is a method by which one party (the prover) convinces another party (the verifier) that a statement is true, without revealing anything beyond the truth of that statement.
# - The verifier learns no extra information about why the statement is true — only that it is true.
#
# Why this matters for blockchains
# - Blockchains like Bitcoin/Ethereum publish transaction data publicly to allow everyone to verify correctness. That public transparency conflicts with privacy needs (e.g., amounts, sender/receiver identity).
# - ZKPs let you prove that a transaction is valid (e.g., funds are available, no double-spend, consensus rules are followed) without revealing sensitive details such as amounts or addresses.
# - They enable privacy-preserving transactions, scalable verification, and certain cryptographic protocols that reduce data published on-chain.
#
# Basic example (intuition)
# - Classic non-crypto metaphor: Peggy (prover) wants to prove to Victor (verifier) she knows the secret password to a cave entrance without telling the password. She goes into the cave and comes out by the correct path that only someone who knows the password could use. Repeating this many times makes Victor confident she knows the password, but he never learns the password itself.
# - In blockchain terms, the “password” might be a secret key or private transaction details; the proof replaces revealing the secret.
#
# Two common ZKP families used in blockchains
# 1. zk-SNARKs (Zero-Knowledge Succinct Non-interactive Arguments of Knowledge)
#    - Non-interactive: the prover generates a single short proof; the verifier checks it without back-and-forth.
#    - Succinct: the proof is small and quick to verify, even if the statement is about a large computation.
#    - Widely used in privacy coins (Zcash) and some layer-2 constructions and rollups.
#    - Typical tradeoffs: require a trusted setup phase for some constructions (though there are zk-SNARKs that avoid trusted setup) and relatively heavy prover computation.
#
# 2. zk-STARKs (Zero-Knowledge Scalable Transparent ARguments of Knowledge)
#    - Transparent: avoid trusted setup by relying on public randomness/hashes.
#    - Scalable: designed for large computations, with stronger post-quantum resistance.
#    - Proof sizes can be larger than SNARKs, but technology keeps improving.
#
# What gets proved on-chain
# - Examples:
#   - A transaction hides amounts but proves the sum of inputs equals sum of outputs + fees.
#   - A user proves they own an account or credential without revealing their identity.
#   - A rollup publishes a succinct ZK proof that a batch of state transitions is valid; nodes can update state by verifying the proof instead of replaying all transactions.
#
# Benefits for blockchain systems
# - Privacy: keeps sensitive data off-chain while still enabling verification.
# - Efficiency / Scalability: succinct proofs let validators accept complex computations quickly (used by ZK rollups).
# - Integrity: provable correctness of off-chain computation or compressed state transitions.
#
# Limitations and tradeoffs
# - Prover cost: generating proofs can be computationally expensive (though improving).
# - Complexity: implementing correct circuits for arbitrary logic is nontrivial.
# - Trusted setup: some ZKP systems historically required a one-time setup that, if compromised, could allow fake proofs (modern variants reduce or remove this need).
# - Proof sizes and verification costs vary by scheme — designers choose based on their priorities (privacy, speed, trust assumptions).
#
# Real-world uses
# - Privacy coins: Zcash uses zk-SNARKs to enable private transactions.
# - ZK rollups: Layer-2 scaling for Ethereum uses ZK proofs to compress many transactions into a single proof posted on-chain (e.g., StarkNet, zkSync).
# - Identity and credentials: proving attributes (over-18, owns-license) without revealing full identity.
#
# In one short sentence
# - A zero-knowledge proof lets you prove "this statement is true" to others on the blockchain without revealing any of the secret data behind that statement — enabling privacy and succinct verification.
#
# If you want, I can:
# - Walk through a simple toy example of a ZKP for a transaction (step-by-step).
# - Compare specific ZKP systems (zk-SNARK vs zk-STARK vs Bulletproofs).
# - Show how ZK rollups work with diagrams (textual) and explain their cost tradeoffs. Which would you like?
# Spending cost: {'total_usd': 0.002162, 'calls': 1}
